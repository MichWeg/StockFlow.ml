# %% [markdown]
# <a href="https://colab.research.google.com/github/MichWeg/StockFlow.ml/blob/main/Testowy_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ssh-keygen -t rsa -b 4096
# Out:
# Generating public/private rsa key pair.
# Enter file in which to save the key (/root/.ssh/id_rsa):
# Created directory '/root/.ssh'.
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /root/.ssh/id_rsa.
# Your public key has been saved in /root/.ssh/id_rsa.pub.
# The key fingerprint is:
# SHA256:Nh219Bj4zbro5liwpr3QYOHZpghkYplkyNJVW6fN7xo root@6e7ff54ae206
# The key's randomart image is:
# +---[RSA 4096]----+
# |o+ .... . ..+    |
# |=.+    o =.o =   |
# |o+o   o . +.oo.  |
# |.+   . + . o. o  |
# |  .   = S . ..   |
# |   . o * + ..    |
# |    . o + E...   |
# |       = ooo.    |
# |      . +=+      |
# +----[SHA256]-----+

# %%
# !ssh-keyscan -t rsa github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-4cec2db4

# %%
# !cat /root/.ssh/id_rsa.pub
# Out:
# ssh-rsa ... root@6e7ff54ae206

# %%
# !ssh -T git@github.com
# Out:
# ...
# Hi MichWeg! You've successfully authenticated, but GitHub does not provide shell access.

# %%
# !git config --global user.email "michal.wegrzynowski@billennium.com"

# %%
# !git config --global user.name "MichWeg"

# %%
# !git clone git@github.com:billennium/talent-hunter-crawler.git
# Out:
# Cloning into 'talent-hunter-crawler'...
# ...
# remote: Enumerating objects: 756, done.
# remote: Counting objects: 100% (756/756), done.
# remote: Compressing objects: 100% (441/441), done.
# remote: Total 756 (delta 411), reused 626 (delta 299), pack-reused 0
# Receiving objects: 100% (756/756), 7.64 MiB | 19.96 MiB/s, done.
# Resolving deltas: 100% (411/411), done.

# %%
cd talent-hunter-crawler/
# Out:
# /content/talent-hunter-crawler

# %%
# !git branch -a
# Out:
# * main
#   remotes/origin/HEAD -> origin/main
#   remotes/origin/bug_facebook_login
#   remotes/origin/develop
#   remotes/origin/facebook-login
#   remotes/origin/getting_group_content_by_loupe
#   remotes/origin/group_content_based_on_criterium
#   remotes/origin/main
#   remotes/origin/modyfing_facebook_data_class
#   remotes/origin/rebuilding_code
#   remotes/origin/saving_data

# %%
# !git checkout remotes/origin/develop
# Out:
# Note: checking out 'remotes/origin/develop'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 5f4f045 Merge brancha Modyfing facebook data class do developa

# %%
# !pip install selenium
# Out:
# ...
#      |████████████████████████████████| 911kB 5.2MB/s
# ...

# %%
# !apt-get update # to update ubuntu to correctly run apt install
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# import sys
# sys.path.insert(0,'/usr/lib/chromium-browser/chromedriver')
# Out:
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file

# %%
# !python main.py
# Out:
# Kod sie odapala
# Page loaded successfully
# Jestem w facebooku
# Traceback (most recent call last):

# %%
import os
os.path.isfile("/content/talent-hunter-crawler/drivers/chromedriver.exe")
# Out:
# True

# %%
# !PATH=$PATH:~content/talent-hunter-crawler/drivers/chromedriver.exe

# %%
# !chmod 777 /content/talent-hunter-crawler/drivers/chromedriver.exe

# %%
/content/talent-hunter-crawler/drivers/chromedriver.exe
